# %%
from astropy.table import Table
import pyfits as fits
import numpy as np
import os.path

# %%
export_path='//Volumes/CJSTORFER/'
download_path = '//Volumes/CJSTORFER/'
catalog_num = '0'

# %%
imgs = 50

cat_lens = Table.read(export_path+'GroundBasedTraining/classifications.csv')
cat_lens= cat_lens[0:imgs]


cat_source = Table.read(export_path+'GroundBasedTraining/classifications.csv')
cat_source= cat_source[0:imgs]

# %%
if os.path.exists(download_path+'GroundBasedTraining/Private_0/Band1/NoLensImage/imageSDSS_R-100002.fits'):
    print 'yes'
# Out:
# yes

# %%
ims_source = np.zeros((imgs, 3, 101, 101))
ims_lens = np.zeros((imgs, 3, 101, 101))
counter = 0
# print ims.shape
# Loads the images
for i, id in enumerate(cat_lens['ID']):
    if (i%10 == 0):
        counter +=1
        print str(counter)+"0 done."
    for j, b in enumerate(['R', 'I', 'G']):
        if os.path.exists(download_path+'GroundBasedTraining/Private_0/Band'+str(j+1)+'/NoSourceImage/imageSDSS_'+b+'-'+str(id)+'.fits'):
            ims_lens[i, j] = fits.getdata(download_path+'GroundBasedTraining/Private_0/Band'+str(j+1)+'/NoSourceImage/imageSDSS_'+b+'-'+str(id)+'.fits')
            print 'yes'
        elif os.path.exists(download_path+'GroundBasedTraining/Private_1/Band'+str(j+1)+'/NoSourceImage/imageSDSS_'+b+'-'+str(id)+'.fits'):
            ims_lens[i, j] = fits.getdata(download_path+'GroundBasedTraining/Private_1/Band'+str(j+1)+'/NoSourceImage/imageSDSS_'+b+'-'+str(id)+'.fits')
            print 'yes'
        else:
            print 'no'
            
            
            
cat_lens['image'] = ims_lens



cat_lens.write(export_path+'catalogs_NoSource_'+str(imgs)+'.hdf5', path='/ground', append=True)

print "Done !"
# Out:
# 10 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# 20 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# 30 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# 40 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# 50 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# Done !

# %%
counter = 0
# print ims.shape
# Loads the images
for i, id in enumerate(cat_source['ID']):
    if (i%10 == 0):
        counter +=1
        print str(counter)+"0 done."
    for j, b in enumerate(['R', 'I', 'G']):         
        if os.path.exists(download_path+'GroundBasedTraining/Private_0/Band'+str(j+1)+'/NoLensImage/imageSDSS_'+b+'-'+str(id)+'.fits'):
            ims_source[i, j] = fits.getdata(download_path+'GroundBasedTraining/Private_0/Band'+str(j+1)+'/NoLensImage/imageSDSS_'+b+'-'+str(id)+'.fits')
            print 'yes'
        elif os.path.exists(download_path+'GroundBasedTraining/Private_1/Band'+str(j+1)+'/NoLensImage/imageSDSS_'+b+'-'+str(id)+'.fits'):
            ims_source[i, j] = fits.getdata(download_path+'GroundBasedTraining/Private_1/Band'+str(j+1)+'/NoLensImage/imageSDSS_'+b+'-'+str(id)+'.fits')
            print 'yes'
        else:
            print 'no'
            
cat_source['image'] = ims_source
cat_source.write(export_path+'catalogs_NoLens_'+str(imgs)+'.hdf5', path='/ground', append=True)
# Out:
# 10 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# 20 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# 30 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# 40 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# 50 done.
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %%
print cat_lens
print cat_source
# Out:
#   ID   is_lens ...            image [3,101,101]
# ------ ------- ... ----------------------------------------
# 100000       1 ...   2.31680614363e-13 .. 3.03521487457e-12
# 100001       0 ...  -7.10818177322e-13 .. 3.39684254032e-13
# 100002       1 ...   1.99357500993e-12 .. 1.06730835107e-12
# 100003       1 ...   -4.16670035064e-13 .. 1.8376912405e-12
# 100004       0 ...  1.55310985427e-12 .. -1.02028777679e-13
# 100005       1 ...  -2.64591321943e-12 .. 2.37910450888e-12
# 100006       0 ...   3.5901408799e-13 .. -1.07293460141e-12
# 100007       1 ...  -3.55716953289e-12 .. 4.68691654498e-13
# 100008       0 ...  -1.28668885442e-12 .. 3.29266074042e-13
# 100009       0 ...  -4.39295897835e-13 .. 1.28404665373e-12
#    ...     ... ...                                      ...
# 100039       0 ...  -1.98966385902e-12 .. 1.58557737252e-12
# 100040       1 ...  -3.13044295347e-13 .. 2.31464868973e-12
# 100041       0 ...   8.70836877002e-13 .. -4.5404028844e-13
# ...

# %%
from astropy.table import Table

d_lens = Table.read(export_path+'catalogs_NoSource_'+str(imgs)+'.hdf5', path='/ground')  # Path to be adjusted on your machine
d_source = Table.read(export_path+'catalogs_NoLens_'+str(imgs)+'.hdf5', path='/ground')  # Path to be adjusted on your machine

d = Table.read('/Users/Chris/Desktop/catalogs_500_RGB.hdf5', path='/ground')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_source = np.array(d_lens['image']).reshape((-1,3,101,101))
x_lens = np.array(d_source['image']).reshape((-1,3,101,101))
x = np.array(d['image']).reshape((-1,3,101,101))[0:50,:,:,:]

# %%
y_source = np.array(d_lens['is_lens']).reshape((-1,1))
y_lens = np.array(d_source['is_lens']).reshape((-1,1))
y = np.array(d['is_lens']).reshape((-1,1))[0:50,:]

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %%
from astropy.visualization import make_lupton_rgb
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename

# %%
i = 40

plt.figure(figsize = (20,20))
plt.subplot(331)
plt.imshow(x_lens[i,0,:,:].T*5e10)
plt.subplot(332)
plt.imshow(x_lens[i,1,:,:].T*5e10)
plt.subplot(333)
plt.imshow(x_lens[i,2,:,:].T*5e10)
plt.subplot(334)
plt.imshow(x_source[i,0,:,:].T*5e10)
plt.subplot(335)
plt.imshow(x_source[i,1,:,:].T*5e10)
plt.subplot(336)
plt.imshow(x_source[i,2,:,:].T*5e10)
plt.subplot(337)
plt.imshow(x[i,0,:,:].T*5e10)
plt.subplot(338)
plt.imshow(x[i,1,:,:].T*5e10)
plt.subplot(339)
plt.imshow(x[i,2,:,:].T*5e10)

# %%
counter = 0
for source,lens,img,targ in zip(x_source,x_lens,x,y):
    rgb_default_lens = np.zeros((3,101,101))
  
    r = img[0]
    idx_r = np.where(r<0)
    r[idx_r]= 0

    i = img[1]
    idx_i = np.where(i<0)
    i[idx_i]= 0
    
    g = img[2]
    idx_g = np.where(g<0)
    g[idx_g]= 0

    g_norm = g*(1/np.max(g))
    r_norm = r*(1/np.max(r))
    i_norm = i*(1/np.max(i))
    fig = plt.figure()
#     ax = fig.add_subplot(111)
#     ax.plot([1],[1])
#     ax.set_yticks([])
#     ax.set_xticks([])

    
    rgb_default = make_lupton_rgb(i_norm, r_norm,g_norm, minimum = 0, Q=0.5, stretch=1)
    if (targ == 0):
        plt.title("non-lens")
    else:
        plt.title("lens")
#     plt.figure(figsize = (20,20))
#     plt.subplot(131)
    plt.imshow(rgb_default)
#     plt.subplot(332)
#     plt.imshow(x_lens[i,1,:,:].T*5e10)
#     plt.subplot(333)
#     plt.imshow(x_lens[i,2,:,:].T*5e10)
    
    
rgb_default.shape
# Out:
# (101, 101, 3)
